# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %%
df = pd.read_csv('../Datasets/vitals.csv')

# %%
df.head()
# Out:
#    patient_id age_group  heart_rate  resp_rate  blood_pressure_systolic  \
# 0           1     Child         106         29                      136
# 1           2     Adult         112         12                      113
# 2           3     Adult         134         20                      115
# 3           4    Infant         119         26                      115
# 4           5    Infant          87         24                      110
#
#    blood_pressure_diastolic  spo2  temperature_c  glucose_mgdl label_status  \
# 0                        61    85           36.9            74     Critical
# 1                        74    96           37.7           150      Warning
# 2                        62    96           38.0           180      Warning
# 3                        70    90           39.0            96     Critical
# 4                        68    95           37.0           101       Normal
#
#   probable_condition
# 0        Not Healthy
# 1        Not Healthy
# 2        Not Healthy
# 3        Not Healthy
# 4            Healthy

# %%
df.columns
# Out:
# Index(['patient_id', 'age_group', 'heart_rate', 'resp_rate',
#        'blood_pressure_systolic', 'blood_pressure_diastolic', 'spo2',
#        'temperature_c', 'glucose_mgdl', 'label_status', 'probable_condition'],
#       dtype='object')

# %%
df.shape
# Out:
# (500, 11)

# %%
df.dtypes
# Out:
# patient_id                    int64
# age_group                    object
# heart_rate                    int64
# resp_rate                     int64
# blood_pressure_systolic       int64
# blood_pressure_diastolic      int64
# spo2                          int64
# temperature_c               float64
# glucose_mgdl                  int64
# label_status                 object
# probable_condition           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   patient_id                500 non-null    int64
#  1   age_group                 500 non-null    object
#  2   heart_rate                500 non-null    int64
#  3   resp_rate                 500 non-null    int64
#  4   blood_pressure_systolic   500 non-null    int64
#  5   blood_pressure_diastolic  500 non-null    int64
#  6   spo2                      500 non-null    int64
#  7   temperature_c             500 non-null    float64
#  8   glucose_mgdl              500 non-null    int64
#  9   label_status              500 non-null    object
#  10  probable_condition        500 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 43.1+ KB

# %%
df.isna().sum()
# Out:
# patient_id                  0
# age_group                   0
# heart_rate                  0
# resp_rate                   0
# blood_pressure_systolic     0
# blood_pressure_diastolic    0
# spo2                        0
# temperature_c               0
# glucose_mgdl                0
# label_status                0
# probable_condition          0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# patient_id                  0
# age_group                   0
# heart_rate                  0
# resp_rate                   0
# blood_pressure_systolic     0
# blood_pressure_diastolic    0
# spo2                        0
# temperature_c               0
# glucose_mgdl                0
# label_status                0
# probable_condition          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                           count      mean         std   min     25%    50%  \
# patient_id                500.0  250.5000  144.481833   1.0  125.75  250.5
# heart_rate                500.0   97.1840   27.304674  50.0   74.00   95.0
# resp_rate                 500.0   18.8740    5.029983  10.0   15.00   19.0
# blood_pressure_systolic   500.0  115.6940   14.354667  90.0  103.00  116.0
# blood_pressure_diastolic  500.0   75.5720    9.228171  60.0   67.00   76.0
# spo2                      500.0   94.7960    4.397392  85.0   92.00   96.0
# temperature_c             500.0   36.8772    0.889755  35.0   36.30   36.7
# glucose_mgdl              500.0  107.9920   28.834542  60.0   84.00  106.0
#
#                              75%    max
# patient_id                375.25  500.0
# heart_rate                115.00  160.0
# resp_rate                  23.00   30.0
# blood_pressure_systolic   128.00  140.0
# blood_pressure_diastolic   84.00   90.0
# spo2                       98.00  100.0
# temperature_c              37.20   39.0
# glucose_mgdl              123.00  180.0

# %%
df['age_group'].unique()
# Out:
# array(['Child', 'Adult', 'Infant', 'Adolescent', 'Elderly'], dtype=object)

# %%
df['age_group'].value_counts().plot(kind='pie')
plt.show()

# %%
df['label_status'].value_counts().plot(kind='bar')
plt.show()

# %%
df['probable_condition'].value_counts().plot(kind='bar')
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df.select_dtypes(include='object').columns.tolist()

# %%
for col in numeric_cols:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    sns.boxplot(x=df[col],vert=False)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
sns.pairplot(df[numeric_cols])
plt.suptitle('Pairplot of Numeric Features', y=1.02)
plt.show()
